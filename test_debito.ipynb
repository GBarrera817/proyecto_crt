# %%
import pandas as pd 
import datetime

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-90e4a22e-322f-4f07-9c07-0c913dd5338d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90e4a22e-322f-4f07-9c07-0c913dd5338d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Bsale 2020 Equipo Beta.xlsx to Bsale 2020 Equipo Beta.xlsx
# Saving Transbank 2020 CRT.xlsx to Transbank 2020 CRT.xlsx
# ...

# %%
#Bsale
xlsxbsale = pd.read_excel("Bsale 2020 Equipo Beta.xlsx", header=0, sheet_name=None)
xlsxbsale
# Out:
# {'Bsale Abril 2020 Equipo Beta':     Boleta Electrónica (154)    Unnamed: 1  ...      Unnamed: 53 Unnamed: 54
#  0             Tipo Documento  Nº Documento  ...  C. Autorización  Nº Voucher
#  1         Boleta Electrónica        103491  ...              NaN         NaN
#  2         Boleta Electrónica        103490  ...              NaN         NaN
#  3         Boleta Electrónica        103489  ...           498500         NaN
#  4         Boleta Electrónica        103488  ...              NaN         NaN
#  ..                       ...           ...  ...              ...         ...
#  272      Factura Electrónica         11313  ...              NaN         NaN
#  273      Factura Electrónica         11312  ...              NaN         NaN
#  274      Factura Electrónica         11311  ...              NaN         NaN
#  275      Factura Electrónica         11310  ...              NaN         NaN
#  276      Factura Electrónica         11309  ...              NaN         NaN
#
# ...

# %%
xlsxbsale.keys()
# Out:
# dict_keys(['Bsale Enero 2020 Equipo Beta', 'Bsale Febrero 2020 Equipo Beta', 'Bsale Marzo 2020 Equipo Beta', 'Bsale Abril 2020 Equipo Beta', 'Bsale Mayo 2020 Equipo Beta', 'Bsale Junio 2020 Equipo Beta', 'Bsale Julio 2020 Equipo Beta', 'Bsale Agosto 2020 Equipo Beta', 'Bsale Septiembre 2020 Equipo Be'])

# %%
df_bsale_enero = xlsxbsale.get('Bsale Enero 2020 Equipo Beta')
df_bsale_enero
# Out:
#           Tipo Documento Nº Documento  ... C. Autorización Nº Voucher.1
# 0     Boleta Electrónica       103116  ...             NaN          NaN
# 1     Boleta Electrónica       103115  ...             NaN          NaN
# 2     Boleta Electrónica       103114  ...          406560          NaN
# 3     Boleta Electrónica       103113  ...             NaN          NaN
# 4     Boleta Electrónica       103112  ...             NaN          NaN
# ..                   ...          ...  ...             ...          ...
# 309  Factura Electrónica        10854  ...             NaN          NaN
# 310  Factura Electrónica        10853  ...             NaN          NaN
# 311  Factura Electrónica        10852  ...             NaN          NaN
# 312  Factura Electrónica        10851  ...             NaN          NaN
# 313  Factura Electrónica        10850  ...             NaN          NaN
#
# [314 rows x 55 columns]

# %%
df_bsale_febrero= xlsxbsale.get('Bsale Febrero 2020 Equipo Beta')
df_bsale_febrero.columns = df_bsale_febrero.iloc[1]

# %%
df_bsale_febrero
# Out:
# 1     Boleta Electrónica        103246  ...              NaN         NaN
# 0         Tipo Documento  Nº Documento  ...  C. Autorización  Nº Voucher
# 1     Boleta Electrónica        103246  ...              NaN         NaN
# 2     Boleta Electrónica        103245  ...              NaN         NaN
# 3     Boleta Electrónica        103244  ...              NaN         NaN
# 4     Boleta Electrónica        103243  ...           571886         NaN
# ..                   ...           ...  ...              ...         ...
# 278  Factura Electrónica         11032  ...           831946         NaN
# 279  Factura Electrónica         11031  ...              NaN         NaN
# 280  Factura Electrónica         11030  ...              NaN         NaN
# 281  Factura Electrónica         11029  ...              NaN         NaN
# 282  Factura Electrónica         11028  ...              NaN         NaN
#
# [283 rows x 55 columns]

# %%
df_bsale_no_comprobante = xlsxbsale.get('N° Comprobante')
df_bsale_no_comprobante
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 309    NaN
# 310    NaN
# 311    NaN
# 312    NaN
# 313    NaN
# Name: N° Comprobante, Length: 314, dtype: object

# %%
# Out:
# nan

# %%
# Leo el excel, estableciendo como encabezado de las columnas la fila 25, y que me muestre el contenido de las hojas

xlsxtransbank = pd.read_excel("Transbank 2020 CRT.xlsx", header=25, sheet_name=None)
xlsxtransbank
# Out:
# {'Credito Abril':    *:Venta anulada en el día, no afecta a comisión y no incluida en TOTALES  ...                Unnamed: 24
#  0                      **:Anulación pareada con venta                        ...                        NaN
#  1                     ***:Cobros pendientes aplicados                        ...                        NaN
#  2                                    Tipo Transacción                        ...                        NaN
#  3                                               Venta                        ...      Abonos de 2 y 3 cuota
#  4                                               Venta                        ...  Pago via webplus (online)
#  ..                                                ...                        ...                        ...
#  65                                              Venta                        ...                        NaN
# ...

# %%
#Obtengo los nombres de las hojas

xlsxtransbank.keys()
# Out:
# dict_keys(['Debito Enero', 'Debito Febrero', 'Experimento Debito Febrero', 'Debito Marzo', 'Credito Enero', 'Credito Febrero', 'Credito Marzo', 'Credito Abril', 'Debito Abril', 'Debito Mayo', 'Debito Junio', 'Debito Julio', 'Credito Mayo', 'Credito Junio', 'Credito Julio', 'Credito Agosto'])

# %%
# Obtengo la hoja de Enero

df_tb_deb_enero = xlsxtransbank.get('Debito Enero')
df_tb_deb_enero
# Out:
#    Tipo Transacción  ...                   Local
# 0             Venta  ...          32914578 - CRT
# 1             Venta  ...          32914578 - CRT
# 2             Venta  ...  29213003 - C.R.T. LTDA
# 3             Venta  ...  29213003 - C.R.T. LTDA
# 4             Venta  ...  29213003 - C.R.T. LTDA
# ..              ...  ...                     ...
# 70            Venta  ...  29213003 - C.R.T. LTDA
# 71            Venta  ...  29213003 - C.R.T. LTDA
# 72            Venta  ...  29213003 - C.R.T. LTDA
# 73            Venta  ...  29213003 - C.R.T. LTDA
# 74            Venta  ...  29213003 - C.R.T. LTDA
#
# [75 rows x 24 columns]

# %%
df_cod_autorizacion = df_tb_deb_enero['Código Autorización Venta']
df_cod_autorizacion
# Out:
# 0     462845
# 1     250069
# 2     293463
# 3        882
# 4       4264
#        ...
# 70    834238
# 71       992
# 72       993
# 73    423680
# 74       998
# Name: Código Autorización Venta, Length: 75, dtype: int64

# %%
df_tb_deb_feb = xlsxtransbank.get('Debito Febrero')

# %%
df_tb_deb_feb
# Out:
#    Tipo Transacción  ...                   Local
# 0             Venta  ...  29213003 - C.R.T. LTDA
# 1             Venta  ...          32914578 - CRT
# 2             Venta  ...          32914578 - CRT
# 3             Venta  ...          32914578 - CRT
# 4             Venta  ...          32914578 - CRT
# 5             Venta  ...          32914578 - CRT
# 6             Venta  ...  29213003 - C.R.T. LTDA
# 7             Venta  ...  29213003 - C.R.T. LTDA
# 8             Venta  ...  29213003 - C.R.T. LTDA
# 9             Venta  ...          32914578 - CRT
# 10            Venta  ...          32914578 - CRT
# 11            Venta  ...  29213003 - C.R.T. LTDA
# 12            Venta  ...  29213003 - C.R.T. LTDA
# 13            Venta  ...  29213003 - C.R.T. LTDA
# 14            Venta  ...  29213003 - C.R.T. LTDA
# 15            Venta  ...  29213003 - C.R.T. LTDA
# 16            Venta  ...  29213003 - C.R.T. LTDA
# 17            Venta  ...  29213003 - C.R.T. LTDA
# ...
