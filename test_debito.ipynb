# %%
import pandas as pd 
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.getcwd()
# Out:
# '/content'

# %%
DAT_FILES_FOLDER = r'datos/2020/'
BSALE_PATH = r'datos/'

# %%
#Bsale
xlsx_bsale = pd.read_excel('/content/drive/MyDrive/proyecto_crt/datos/docSearchExport_cc0f2b54bf6e4b085d07fc2bdcdabf5fd73b1843.xlsx', header=11, sheet_name=None)
xlsx_bsale
# Out:
# {'docSearchExport_cc0f2b54bf6e4b0':                 Tipo Documento Nº Documento  ... Unnamed: 113 Unnamed: 114
#  0           Boleta Electrónica       103491  ...          NaT          NaN
#  1           Boleta Electrónica       103490  ...          NaT          NaN
#  2           Boleta Electrónica       103489  ...          NaT          NaN
#  3           Boleta Electrónica       103488  ...          NaT          NaN
#  4           Boleta Electrónica       103487  ...          NaT          NaN
#  ...                        ...          ...  ...          ...          ...
#  2101  Pedido web Mercado Libre           19  ...          NaT          NaN
#  2102  Pedido web Mercado Libre           18  ...          NaT          NaN
#  2103  Pedido web Mercado Libre           17  ...          NaT          NaN
#  2104  Pedido web Mercado Libre           16  ...          NaT          NaN
#  2105                       NaN          NaN  ...          NaT          NaN
#
# ...

# %%
#Obtengo el nombre de las hojas del excel
xlsx_bsale.keys()
# Out:
# dict_keys(['docSearchExport_cc0f2b54bf6e4b0'])

# %%
#Obtengo la hoja de nombre específico
df_bsale = xlsx_bsale.get('docSearchExport_cc0f2b54bf6e4b0')
df_bsale
# Out:
#                 Tipo Documento Nº Documento  ... Unnamed: 113 Unnamed: 114
# 0           Boleta Electrónica       103491  ...          NaT          NaN
# 1           Boleta Electrónica       103490  ...          NaT          NaN
# 2           Boleta Electrónica       103489  ...          NaT          NaN
# 3           Boleta Electrónica       103488  ...          NaT          NaN
# 4           Boleta Electrónica       103487  ...          NaT          NaN
# ...                        ...          ...  ...          ...          ...
# 2101  Pedido web Mercado Libre           19  ...          NaT          NaN
# 2102  Pedido web Mercado Libre           18  ...          NaT          NaN
# 2103  Pedido web Mercado Libre           17  ...          NaT          NaN
# 2104  Pedido web Mercado Libre           16  ...          NaT          NaN
# 2105                       NaN          NaN  ...          NaT          NaN
#
# [2106 rows x 115 columns]

# %%
# Obtengo el nombre de las columnas
df_bsale.columns
# Out:
# Index(['Tipo Documento', 'Nº Documento', 'Condicion de Venta', 'Fecha Emision',
#        'Fecha Vencimiento', 'Código Tributario', 'Monto Neto Documento',
#        'Monto Impuestos Documento', 'Monto Exento Documento',
#        'Monto Documento',
#        ...
#        'Unnamed: 105', 'Unnamed: 106', 'Unnamed: 107', 'Unnamed: 108',
#        'Unnamed: 109', 'Unnamed: 110', 'Unnamed: 111', 'Unnamed: 112',
#        'Unnamed: 113', 'Unnamed: 114'],
#       dtype='object', length=115)

# %%
# Separo el archivo bsale con los datos de Boleta y Factura
df_bsale_bol_fact = df_bsale[(df_bsale['Tipo Documento'] == 'Boleta Electrónica') | (df_bsale['Tipo Documento'] == 'Factura Electrónica')]

df_bsale_bol_fact
# Out:
#            Tipo Documento Nº Documento  ... Unnamed: 113 Unnamed: 114
# 0      Boleta Electrónica       103491  ...          NaT          NaN
# 1      Boleta Electrónica       103490  ...          NaT          NaN
# 2      Boleta Electrónica       103489  ...          NaT          NaN
# 3      Boleta Electrónica       103488  ...          NaT          NaN
# 4      Boleta Electrónica       103487  ...          NaT          NaN
# ...                   ...          ...  ...          ...          ...
# 1738  Factura Electrónica        10854  ...          NaT          NaN
# 1739  Factura Electrónica        10853  ...          NaT          NaN
# 1740  Factura Electrónica        10852  ...          NaT          NaN
# 1741  Factura Electrónica        10851  ...          NaT          NaN
# 1742  Factura Electrónica        10850  ...          NaT          NaN
#
# [1088 rows x 115 columns]

# %%
df_tb_deb_enero = pd.read_csv('/content/drive/MyDrive/proyecto_crt/datos/2020/02_extraccion-masiva-debito-pesos-1-al-31-01-2020(24-11-2020_20.49.00).csv', delimiter=';')
df_tb_deb_enero
# Out:
#    Tipo Transacción       Fecha Venta  ...                   Local Unnamed: 24
# 0             Venta      31/01/2020    ...  29213003 - C.R.T. LTDA         NaN
# 1             Venta      03/02/2020    ...  29213003 - C.R.T. LTDA         NaN
# 2             Venta      05/02/2020    ...  29213003 - C.R.T. LTDA         NaN
# 3             Venta      06/02/2020    ...  29213003 - C.R.T. LTDA         NaN
# 4             Venta      06/02/2020    ...  29213003 - C.R.T. LTDA         NaN
# ..              ...               ...  ...                     ...         ...
# 62            Venta  26/04/2020 17:22  ...          32914578 - CRT         NaN
# 63            Venta  28/04/2020 09:58  ...          32914578 - CRT         NaN
# 64            Venta  28/04/2020 14:01  ...          32914578 - CRT         NaN
# 65        Anulación  17/04/2020 13:30  ...          32914578 - CRT         NaN
# 66         Servicio      31/03/2020    ...  27863035 - C.R.T. LTDA         NaN
#
# [67 rows x 25 columns]

# %%
df_tb_deb_febrero = pd.read_csv('/content/drive/MyDrive/proyecto_crt/datos/2020/03_extraccion-masiva-debito-pesos-1-al-29-02-2020(24-11-2020_20.49.15).csv', delimiter=';')
df_tb_deb_febrero
# Out:
#    Tipo Transacción       Fecha Venta  ...                   Local Unnamed: 24
# 0             Venta      31/01/2020    ...  29213003 - C.R.T. LTDA         NaN
# 1             Venta      03/02/2020    ...  29213003 - C.R.T. LTDA         NaN
# 2             Venta      05/02/2020    ...  29213003 - C.R.T. LTDA         NaN
# 3             Venta      06/02/2020    ...  29213003 - C.R.T. LTDA         NaN
# 4             Venta      06/02/2020    ...  29213003 - C.R.T. LTDA         NaN
# ..              ...               ...  ...                     ...         ...
# 62            Venta  26/04/2020 17:22  ...          32914578 - CRT         NaN
# 63            Venta  28/04/2020 09:58  ...          32914578 - CRT         NaN
# 64            Venta  28/04/2020 14:01  ...          32914578 - CRT         NaN
# 65        Anulación  17/04/2020 13:30  ...          32914578 - CRT         NaN
# 66         Servicio      31/03/2020    ...  27863035 - C.R.T. LTDA         NaN
#
# [67 rows x 25 columns]

# %%
boletas = []
trucheo = []

for indice, boleta in zip(df_tb_deb_febrero.index, df_tb_deb_febrero['Nº Boleta']):
  bol = df_bsale_bol_fact[df_bsale_bol_fact.eq(df_tb_deb_febrero['Código Autorización Venta'][indice]).any(1)]
  if len(bol) == 1:
    bol = bol['Nº Documento'].item()
    boletas.append(bol)
  #No se encontró  
  elif len(bol) == 0:
    bol = "Apocalipsis Zombie!!"
    boletas.append(bol)
  # Hay duplicados
  else:
    bol = "Duplicado o +"
    boletas.append(bol)
    trucheo.append(indice)

# %%
print(boletas)
print(trucheo)
# Out:
# [103116, 103124, 'Apocalipsis Zombie!!', 103144, 103142, 103140, 103151, 'Apocalipsis Zombie!!', 103155, 103161, 103176, 'Apocalipsis Zombie!!', 'Apocalipsis Zombie!!', 103208, 11147, 103252, 103255, 103273, 103280, 11215, 103285, 103298, 103297, 103327, 103329, 103332, 103335, 103337, 'Apocalipsis Zombie!!', 103361, 103363, 11337, 103369, 103371, 103372, 103376, 103381, 103394, 103393, 'Apocalipsis Zombie!!', 103396, 103397, 103403, 103404, 11366, 103407, 103420, 'Apocalipsis Zombie!!', 'Apocalipsis Zombie!!', 103423, 'Apocalipsis Zombie!!', 11384, 103429, 11390, 'Apocalipsis Zombie!!', 103441, 103447, 103449, 'Apocalipsis Zombie!!', 103460, 103456, 103470, 103484, 'Apocalipsis Zombie!!', 'Apocalipsis Zombie!!']
# [10, 25]

# %%
print(boletas)
len(boletas)
# Out:
# [103116, 103124, 'Apocalipsis Zombie!!', 103144, 103142, 103140, 103151, 'Apocalipsis Zombie!!', 103155, 103161, 'Duplicado o +', 103176, 'Apocalipsis Zombie!!', 'Apocalipsis Zombie!!', 103208, 11147, 103252, 103255, 103273, 103280, 11215, 103285, 103298, 103297, 103327, 'Duplicado o +', 103329, 103332, 103335, 103337, 'Apocalipsis Zombie!!', 103361, 103363, 11337, 103369, 103371, 103372, 103376, 103381, 103394, 103393, 'Apocalipsis Zombie!!', 103396, 103397, 103403, 103404, 11366, 103407, 103420, 'Apocalipsis Zombie!!', 'Apocalipsis Zombie!!', 103423, 'Apocalipsis Zombie!!', 11384, 103429, 11390, 'Apocalipsis Zombie!!', 103441, 103447, 103449, 'Apocalipsis Zombie!!', 103460, 103456, 103470, 103484, 'Apocalipsis Zombie!!', 'Apocalipsis Zombie!!']
# 67

# %%
df_bsale_bol_fact[df_bsale_bol_fact.eq(df_tb_deb_febrero['Código Autorización Venta'][66]).any(1)]
# Out:
# Empty DataFrame
# ...

# %%
df_tb_deb_febrero['Código Autorización Venta'][25]
# Out:
# 811598.0

# %%
df_tb_deb_febrero['boletas_completas'] = boletas

# %%
df_tb_deb_febrero.loc[:, ['Código Autorización Venta', 'boletas_completas', 'Nº Boleta']]
# Out:
#     Código Autorización Venta     boletas_completas   Nº Boleta
# 0                    872443.0                103116
# 1                    469397.0                103124
# 2                    208669.0  Apocalipsis Zombie!!
# 3                    344139.0                103144
# 4                    397586.0                103142
# ..                        ...                   ...         ...
# 62                   943085.0                103456  0000000000
# 63                   192561.0                103470  0000000000
# 64                   186098.0                103484  0000000000
# 65                   486523.0  Apocalipsis Zombie!!  0000000000
# 66                        NaN  Apocalipsis Zombie!!         NaN
#
# [67 rows x 3 columns]
